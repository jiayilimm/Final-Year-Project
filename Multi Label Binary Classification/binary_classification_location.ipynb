# %%
import nltk
import string
# nltk.download('all')
import re
from nltk.corpus import stopwords
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.layers import Embedding
from keras.layers import Dense, Flatten, LSTM, Bidirectional
from keras.layers import Input, GlobalMaxPool1D, Dropout
from keras.layers import Activation
from keras.models import Model, Sequential
from keras import optimizers
from keras.utils.vis_utils import plot_model

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pylab as pl
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("classification.csv")
train, test = train_test_split(df, test_size=0.1, random_state=42)

# %%
#divide our training data into features X and label Y
X_train = train['sentence'] #will be used to train our model on
X_test = test['sentence'] #will be used to predict the output labels to see how well our model has trained
y_train = train[['Location']].values
y_test = test[['Location']].values

# %%
y_train.shape
# Out:
# (1893, 1)

# %%
punct = '!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~“”'

# %% [markdown]
# Clean Text

# %%
def clean_text(txt):
  txt = txt.strip() #remove additional white space before and after end of sentence
  # txt = txt.lower()
  txt = txt.replace("'s", "") # remove apostrophe s
  txt = txt.replace("\?a.m.", "am") # replace a.m.
  txt = txt.replace("\?p.m.", "pm") # replace p.m.
  text = "".join([c for c in txt if c not in punct]) #remove punct
  text = text.replace(u'\u2014', "")
  new_text = text.replace(r"\s+", " ") #remove additional space

  return new_text

# %%
#cleans train and test text  
x_train, x_test = [], []
for sentence in X_train:
  x_train.append(clean_text(sentence))

for sentence in X_test:
  x_test.append(clean_text(sentence))

# %%
from keras.preprocessing.text import Tokenizer
#calculate the vocabulary size as well which will be given as an input to the Embedding layer
tokens = Tokenizer() 
tokens.fit_on_texts(x_train)
vocab_size = len(tokens.word_index) + 1 #size of the total number of uniques tokens in our dataset
tokenized_train = tokens.texts_to_sequences(x_train) #converting our tokens into sequence of integers
tokenized_test = tokens.texts_to_sequences(x_test)

# %%
print(x_train[0]) #the first text
print(100 * '-')
print(tokenized_train[0]) #the correspondin first comment in the vectorized form
# Out:
# The incident happened at Balogu North a suburb of Yendi around 1830GMT on Monday August 31
# ----------------------------------------------------------------------------------------------------
# [1, 98, 61, 10, 2298, 101, 2, 1487, 4, 1488, 35, 2299, 8, 47, 202, 436]

# %% [markdown]
# **Pad Sequences**

# %%
from keras.preprocessing.sequence import pad_sequences

max_len = 334 #max length of the padded sequence (one of the hyperparameter that can be tuned)
padded_train = pad_sequences(tokenized_train, maxlen = max_len, padding = 'post') #post padding our sequences with zeros
padded_test = pad_sequences(tokenized_test, maxlen = max_len)

# %%
padded_train[:10]
# Out:
# array([[   1,   98,   61, ...,    0,    0,    0],
#        [ 569,  235,    9, ...,    0,    0,    0],
#        [   1,   81,  272, ...,    0,    0,    0],
#        ...,
#        [2305, 2306, 2307, ...,    0,    0,    0],
#        [ 510,  472,  369, ...,    0,    0,    0],
#        [ 569,  235,  223, ...,    0,    0,    0]], dtype=int32)

# %% [markdown]
# **GLOVE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

embedding_dim = 50
#def create_embedding_matrix(filepath, embedding_dim):
vocab_size = len(tokens.word_index) + 1  # Adding again 1 because of reserved 0 index
embedding_matrix = np.zeros((vocab_size, embedding_dim))

with open('/content/drive/MyDrive/FYP/glove.6B.50d.txt', encoding = 'utf-8') as f:
    for line in f:
        word, *vector = line.split()
        if word in tokens.word_index:
            idx = tokens.word_index[word] 
            embedding_matrix[idx] = np.array(vector, dtype=np.float32)[:embedding_dim]

# %%
model1 = Sequential()
model1.add(Embedding(vocab_size, embedding_dim, weights = [embedding_matrix], input_length = max_len, trainable = False))
model1.add(LSTM(60, return_sequences = True))
model1.add(Activation('relu'))
model1.add(GlobalMaxPool1D())
model1.add(Dropout(0.0001))
model1.add(Dense(150, activation = 'relu'))
model1.add(Dropout(0.0001))
model1.add(Dense(50, activation = 'relu'))
model1.add(Dropout(0.0001))
model1.add(Dense(1, activation = 'sigmoid'))
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 334, 50)           249300
# _________________________________________________________________
# lstm (LSTM)                  (None, 334, 60)           26640
# _________________________________________________________________
# activation (Activation)      (None, 334, 60)           0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 60)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 60)                0
# _________________________________________________________________
# dense (Dense)                (None, 150)               9150
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                7550
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 292,691
# Trainable params: 43,391
# Non-trainable params: 249,300
# _________________________________________________________________

# %%
plot_model(model1, to_file='LSTM_Location_Architecture.png', show_shapes=True, show_layer_names=True)

# %%
model1.compile(loss = 'binary_crossentropy', optimizer = 'adam',  metrics = ['acc'])
history1 = model1.fit(padded_train, y_train, epochs = 5, batch_size = 128, validation_split = 0.1)
# Out:
# Epoch 1/5
# 14/14 [==============================] - 5s 76ms/step - loss: 0.6635 - acc: 0.5825 - val_loss: 0.6144 - val_acc: 0.6632
# Epoch 2/5
# 14/14 [==============================] - 0s 23ms/step - loss: 0.5641 - acc: 0.7283 - val_loss: 0.4689 - val_acc: 0.8263
# Epoch 3/5
# 14/14 [==============================] - 0s 20ms/step - loss: 0.4333 - acc: 0.8221 - val_loss: 0.3607 - val_acc: 0.8737
# Epoch 4/5
# 14/14 [==============================] - 0s 20ms/step - loss: 0.3354 - acc: 0.8680 - val_loss: 0.3092 - val_acc: 0.9000
# Epoch 5/5
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2903 - acc: 0.8872 - val_loss: 0.3040 - val_acc: 0.8895

# %%
max(history1.history['acc'])
# Out:
# 0.8749266266822815

# %%
max(history1.history['val_acc'])
# Out:
# 0.8999999761581421

# %%
plt.plot(history1.history['acc'])
plt.plot(history1.history['val_acc'])
plt.title('model acc')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model1.load_weights('/content/Location_GloVe_LSTM_B128_Epoch5.h5')
model1.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['acc'])

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model1.evaluate(padded_test, y_test, batch_size=128)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 2/2 [==============================] - 30s 29ms/step - loss: 0.3201 - acc: 0.8673
# test loss, test acc: [0.3170453906059265, 0.8672986030578613]

# %%
# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print("Generate predictions for 3 samples")
predictions1 = model1.predict(padded_test)
print("predictions shape:", predictions1.shape)
print("predictions shape:\n", predictions1[1:5])
# Out:
# Generate predictions for 3 samples
# predictions shape: (211, 1)
# predictions shape:
#  [[0.08633603]
#  [0.10080987]
#  [0.83442044]
#  [0.9976799 ]]

# %%
y_test[1:5]
# Out:
# array([[0],
#        [0],
#        [1],
#        [1]])

# %%
cm = confusion_matrix(y_test, predictions1.round())
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt='g'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Location LSTM Confusion Matrix') 
ax.xaxis.set_ticklabels(['No', 'Yes'])
ax.yaxis.set_ticklabels(['No', 'Yes'])
# Out:
# [Text(0, 0.5, 'No'), Text(0, 1.5, 'Yes')]

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
print ("Batch Size: ", 16)
print ("LSTM Classification report: \n", (classification_report(y_test, predictions1.round())))
# Out:
# Batch Size:  16
# LSTM Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86        99
#            1       0.88      0.87      0.87       112
#
#     accuracy                           0.87       211
#    macro avg       0.87      0.87      0.87       211
# weighted avg       0.87      0.87      0.87       211

# %%
# model1.save_weights('Location_GloVe_LSTM_B128_Epoch5.h5')

# %% [markdown]
# **GLOVE - BILSTM**

# %%
model2 = Sequential()
model2.add(Embedding(vocab_size, embedding_dim, weights = [embedding_matrix], input_length = max_len, trainable = False))
model2.add(Bidirectional(LSTM(60, return_sequences = True)))
model2.add(Activation('relu'))
model2.add(GlobalMaxPool1D())
model2.add(Dropout(0.0001))
model2.add(Dense(150, activation = 'relu'))
model2.add(Dropout(0.0001))
model2.add(Dense(50, activation = 'relu'))
model2.add(Dropout(0.0001))
model2.add(Dense(1, activation = 'sigmoid'))
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 334, 50)           249300
# _________________________________________________________________
# bidirectional (Bidirectional (None, 334, 120)          53280
# _________________________________________________________________
# activation_1 (Activation)    (None, 334, 120)          0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 150)               18150
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                7550
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 328,331
# Trainable params: 79,031
# Non-trainable params: 249,300
# _________________________________________________________________

# %%
plot_model(model2, to_file='BILSTM_Location_Architecture.png', show_shapes=True, show_layer_names=True)

# %%
model2.compile(loss = 'binary_crossentropy', optimizer = 'adam',  metrics = ['acc'])
history2 = model2.fit(padded_train, y_train, epochs = 5, batch_size = 128, validation_split = 0.1)
# Out:
# Epoch 1/5
# 14/14 [==============================] - 4s 94ms/step - loss: 0.6608 - acc: 0.5590 - val_loss: 0.5574 - val_acc: 0.7632
# Epoch 2/5
# 14/14 [==============================] - 0s 35ms/step - loss: 0.5123 - acc: 0.7853 - val_loss: 0.3896 - val_acc: 0.8526
# Epoch 3/5
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3885 - acc: 0.8375 - val_loss: 0.3228 - val_acc: 0.8895
# Epoch 4/5
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3219 - acc: 0.8514 - val_loss: 0.3090 - val_acc: 0.8895
# Epoch 5/5
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2954 - acc: 0.8812 - val_loss: 0.2867 - val_acc: 0.9053

# %%
max(history2.history['acc'])
# Out:
# 0.8813858032226562

# %%
max(history2.history['val_acc'])
# Out:
# 0.9052631855010986

# %%
plt.plot(history2.history['acc'])
plt.plot(history2.history['val_acc'])
plt.title('BiLSTM Model Acc')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('BiLSTM Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model2.load_weights('/content/Location_GloVe_BiLSTM_B128_Epoch5.h5')
model2.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['acc'])

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results2 = model2.evaluate(padded_test, y_test, batch_size=16)
print("test loss, test acc:", results2)
# Out:
# Evaluate on test data
# 14/14 [==============================] - 2s 44ms/step - loss: 0.2998 - acc: 0.9039
# test loss, test acc: [0.3403744101524353, 0.8767772316932678]

# %%
# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print("Generate predictions for 3 samples")
predictions2 = model2.predict(padded_test)
print("predictions shape:", predictions2.shape)
print("predictions shape:\n", predictions2[:10])
# Out:
# Generate predictions for 3 samples
# predictions shape: (211, 1)
# predictions shape:
#  [[0.05111066]
#  [0.1087842 ]
#  [0.17227769]
#  [0.7465904 ]
#  [0.9988998 ]
#  [0.07622533]
#  [0.65303814]
#  [0.1685485 ]
#  [0.0632139 ]
#  [0.28627712]]

# %%
y_test[:10]
# Out:
# array([[0],
#        [0],
#        [0],
#        [1],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [0]])

# %%
cm = confusion_matrix(y_test, predictions2.round())
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt='g'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Location BiLSTM Confusion Matrix') 
ax.xaxis.set_ticklabels(['No', 'Yes'])
ax.yaxis.set_ticklabels(['No', 'Yes'])
# Out:
# [Text(0, 0.5, 'No'), Text(0, 1.5, 'Yes')]

# %%
print ("Batch Size: ", 128)
print ("BiLSTM Classification report: \n", (classification_report(y_test, predictions2.round())))
# Out:
# Batch Size:  128
# BiLSTM Classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        99
#            1       0.88      0.89      0.88       112
#
#     accuracy                           0.88       211
#    macro avg       0.88      0.88      0.88       211
# weighted avg       0.88      0.88      0.88       211

# %%
# model2.save_weights('Location_GloVe_BiLSTM_B128_Epoch5.h5')
